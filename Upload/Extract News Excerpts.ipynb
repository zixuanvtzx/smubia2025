# %%
import pandas as pd
import spacy

# Load the spaCy language model
nlp = spacy.load("en_core_web_sm")

# Load the Excel file
file_path = 'news_excerpts_parsed.xlsx'
df = pd.read_excel(file_path)

# Containers for original lists
tokens_list = []
pos_tags_list = []
named_entities_list = []

# Dictionary to aggregate entity relationships and counts
entity_data = {}

# Process each news excerpt
for idx, text in enumerate(df['Text']):
    doc = nlp(text)
    
    # Extract meaningful tokens (non-stop words, lowercase, and no punctuation)
    filtered_tokens = [token.text.lower() for token in doc if not token.is_stop and token.is_alpha]
    tokens_list.append(filtered_tokens)

    # Extract POS tags for non-stop words (lowercased)
    pos_tags = [(token.text.lower(), token.pos_) for token in doc if not token.is_stop and token.is_alpha]
    pos_tags_list.append(pos_tags)

    # Extract Named Entities (lowercased and without punctuation)
    named_entities = [(ent.text.lower(), ent.label_) for ent in doc.ents if ent.text.isalnum()]
    named_entities_list.append(named_entities)

    # Build dictionary for entity relationships
    for entity_text, entity_label in named_entities:
        key = (entity_text, entity_label)  # Use lowercased entity text
        if key not in entity_data:
            entity_data[key] = {
                "Entity": entity_text,
                "Entity Type": entity_label,
                "Count": 0,
                "Excerpt Sources": set()
            }
        entity_data[key]["Count"] += 1
        entity_data[key]["Excerpt Sources"].add(idx + 1)

# Prepare relationship DataFrame
relationship_data = [
    {
        "Entity": entity_info["Entity"],
        "Entity Type": entity_info["Entity Type"],
        "Count": entity_info["Count"],
        "Excerpt Sources": ", ".join(map(str, entity_info["Excerpt Sources"]))
    }
    for entity_info in entity_data.values()
]

# Save lists back to the original DataFrame
df['Tokens'] = tokens_list
df['POS_Tags'] = pos_tags_list
df['Named_Entities'] = named_entities_list

# Save the updated original Excel file
df.to_excel('news_excerpts_with_lists.xlsx', index=False)

# Save the enhanced relationship analysis
relationship_df = pd.DataFrame(relationship_data)
relationship_df.sort_values(by='Count', ascending=False, inplace=True)
relationship_df.to_excel('enhanced_entity_relationship_analysis.xlsx', index=False)

print("Both files are generated:")
print("- 'news_excerpts_with_lists.xlsx' for the original lists.")
print("- 'enhanced_entity_relationship_analysis.xlsx' for relationship analysis.")
# Out:
# Both files are generated:
# - 'news_excerpts_with_lists.xlsx' for the original lists.
# - 'enhanced_entity_relationship_analysis.xlsx' for relationship analysis.

# %%
for i in range(10):
    print(i)
    print("Tokens:", tokens_list[i])
    print("POS Tags:", pos_tags_list[i])
    print("Named Entities:", named_entities_list[i])
    print()
# Out:
# 0
# Tokens: ['Starbucks', 'violated', 'federal', 'labor', 'law', 'increased', 'wages', 'offered', 'new', 'perks', 'benefits', 'non', 'union', 'employees', 'National', 'Labor', 'Relations', 'Board', 'judge', 'found', 'Thursday', 'decision', 'latest', 'series', 'NLRB', 'rulings', 'finding', 'Starbucks', 'violated', 'labor', 'law', 'efforts', 'stop', 'unions', 'forming', 'coffee', 'shops', 'issue', 'heart', 'case', 'current', 'Board', 'law', 'Starbucks', 'entitled', 'explicitly', 'reward', 'employees', 'participating', 'union', 'activity', 'falsely', 'telling', 'workers', 'federal', 'labor', 'law', 'forced', 'action', 'wrote', 'administrative', 'law', 'judge', 'Mara', 'Louise', 'Anzalone']
# POS Tags: [('Starbucks', 'PROPN'), ('violated', 'VERB'), ('federal', 'ADJ'), ('labor', 'NOUN'), ('law', 'NOUN'), ('increased', 'VERB'), ('wages', 'NOUN'), ('offered', 'VERB'), ('new', 'ADJ'), ('perks', 'NOUN'), ('benefits', 'NOUN'), ('non', 'ADJ'), ('union', 'ADJ'), ('employees', 'NOUN'), ('National', 'PROPN'), ('Labor', 'PROPN'), ('Relations', 'PROPN'), ('Board', 'PROPN'), ('judge', 'NOUN'), ('found', 'VERB'), ('Thursday', 'PROPN'), ('decision', 'NOUN'), ('latest', 'ADJ'), ('series', 'NOUN'), ('NLRB', 'ADJ'), ('rulings', 'NOUN'), ('finding', 'VERB'), ('Starbucks', 'PROPN'), ('violated', 'VERB'), ('labor', 'NOUN'), ('law', 'NOUN'), ('efforts', 'NOUN'), ('stop', 'VERB'), ('unions', 'NOUN'), ('forming', 'VERB'), ('coffee', 'NOUN'), ('shops', 'NOUN'), ('issue', 'NOUN'), ('heart', 'NOUN'), ('case', 'NOUN'), ('current', 'ADJ'), ('Board', 'PROPN'), ('law', 'NOUN'), ('Starbucks', 'PROPN'), ('entitled', 'VERB'), ('explicitly', 'ADV'), ('reward', 'VERB'), ('employees', 'NOUN'), ('participating', 'VERB'), ('union', 'NOUN'), ('activity', 'NOUN'), ('falsely', 'ADV'), ('telling', 'VERB'), ('workers', 'NOUN'), ('federal', 'ADJ'), ('labor', 'NOUN'), ('law', 'NOUN'), ('forced', 'VERB'), ('action', 'NOUN'), ('wrote', 'VERB'), ('administrative', 'ADJ'), ('law', 'NOUN'), ('judge', 'NOUN'), ('Mara', 'PROPN'), ('Louise', 'PROPN'), ('Anzalone', 'PROPN')]
# Named Entities: [('National Labor Relations Board', 'ORG'), ('Thursday', 'DATE'), ('NLRB', 'ORG'), ('Starbucks', 'ORG'), ('Board', 'ORG'), ('Mara-Louise Anzalone', 'PERSON')]
#
# 1
# Tokens: ['suspect', 'plead', 'guilty', 'Singapore', 'largest', 'money', 'laundering', 'case', 'convicted', 'sentenced', 'months', 'jail', 'district', 'court', 'Tuesday', 'Apr', 'Su', 'Wenqiang', 'admitted', 'charges', 'money', 'laundering', 'possessing', 'proceeds', 'illegal', 'remote', 'gambling', 'offences', 'lying', 'work', 'passes', 'wife', 'billion', 'billion', 'assets', 'seized', 'frozen', 'relation', 'case', 'likely', 'makes', 'largest', 'money', 'laundering', 'operations', 'world', 'Su', 'suspects', 'arrested', 'simultaneous', 'police', 'raids', 'August', 'Cambodian', 'national', 'passport', 'states', 'Fujian', 'nabbed', 'Good', 'Class', 'Bungalow', 'Lewis', 'Road', 'Bukit', 'Timah']
# POS Tags: [('suspect', 'NOUN'), ('plead', 'VERB'), ('guilty', 'ADJ'), ('Singapore', 'PROPN'), ('largest', 'ADJ'), ('money', 'NOUN'), ('laundering', 'NOUN'), ('case', 'NOUN'), ('convicted', 'VERB'), ('sentenced', 'VERB'), ('months', 'NOUN'), ('jail', 'NOUN'), ('district', 'NOUN'), ('court', 'NOUN'), ('Tuesday', 'PROPN'), ('Apr', 'PROPN'), ('Su', 'PROPN'), ('Wenqiang', 'PROPN'), ('admitted', 'VERB'), ('charges', 'NOUN'), ('money', 'NOUN'), ('laundering', 'NOUN'), ('possessing', 'VERB'), ('proceeds', 'NOUN'), ('illegal', 'ADJ'), ('remote', 'ADJ'), ('gambling', 'NOUN'), ('offences', 'NOUN'), ('lying', 'VERB'), ('work', 'NOUN'), ('passes', 'VERB'), ('wife', 'NOUN'), ('billion', 'NUM'), ('billion', 'NUM'), ('assets', 'NOUN'), ('seized', 'VERB'), ('frozen', 'VERB'), ('relation', 'NOUN'), ('case', 'NOUN'), ('likely', 'ADV'), ('makes', 'VERB'), ('largest', 'ADJ'), ('money', 'NOUN'), ('laundering', 'VERB'), ('operations', 'NOUN'), ('world', 'NOUN'), ('Su', 'PROPN'), ('suspects', 'NOUN'), ('arrested', 'VERB'), ('simultaneous', 'ADJ'), ('police', 'NOUN'), ('raids', 'NOUN'), ('August', 'PROPN'), ('Cambodian', 'ADJ'), ('national', 'NOUN'), ('passport', 'NOUN'), ('states', 'VERB'), ('Fujian', 'PROPN'), ('nabbed', 'VERB'), ('Good', 'PROPN'), ('Class', 'PROPN'), ('Bungalow', 'PROPN'), ('Lewis', 'PROPN'), ('Road', 'PROPN'), ('Bukit', 'PROPN'), ('Timah', 'PROPN')]
# Named Entities: [('first', 'ORDINAL'), ('Singapore', 'GPE'), ("13 months'", 'DATE'), ('Tuesday', 'DATE'), ('2', 'CARDINAL'), ('Su Wenqiang', 'PERSON'), ('32', 'DATE'), ('11', 'CARDINAL'), ('More than S$3 billion', 'MONEY'), ('US$2.2 billion', 'MONEY'), ('Su', 'PERSON'), ('10', 'CARDINAL'), ('last August', 'DATE'), ('Cambodian', 'NORP'), ('Fujian', 'GPE'), ('Lewis Road', 'FAC'), ('Bukit Timah', 'ORG')]
#
# 2
# Tokens: ['Meta', 'fined', 'record', 'breaking', 'billion', 'billion', 'European', 'Union', 'regulators', 'violating', 'EU', 'privacy', 'laws', 'transferring', 'personal', 'data', 'Facebook', 'users', 'servers', 'United', 'States', 'European', 'Data', 'Protection', 'Board', 'announced', 'fine', 'statement', 'Monday', 'saying', 'followed', 'inquiry', 'Facebook', 'FB', 'Irish', 'Data', 'Protection', 'Commission', 'chief', 'regulator', 'overseeing', 'Meta', 'operations', 'Europe', 'highlights', 'ongoing', 'uncertainty', 'global', 'businesses', 'legally', 'transfer', 'EU', 'users', 'data', 'servers', 'overseas', 'EU', 'regulator', 'said', 'processing', 'storage', 'personal', 'data', 'United', 'States', 'contravened', 'Europe', 'signature', 'data', 'privacy', 'law', 'known', 'General', 'Data', 'Protection', 'Regulation', 'Chapter', 'GDPR', 'sets', 'conditions', 'personal', 'data', 'transferred', 'countries', 'international', 'organizations']
# POS Tags: [('Meta', 'PROPN'), ('fined', 'VERB'), ('record', 'NOUN'), ('breaking', 'VERB'), ('billion', 'NUM'), ('billion', 'NUM'), ('European', 'PROPN'), ('Union', 'PROPN'), ('regulators', 'NOUN'), ('violating', 'VERB'), ('EU', 'PROPN'), ('privacy', 'NOUN'), ('laws', 'NOUN'), ('transferring', 'VERB'), ('personal', 'ADJ'), ('data', 'NOUN'), ('Facebook', 'PROPN'), ('users', 'NOUN'), ('servers', 'NOUN'), ('United', 'PROPN'), ('States', 'PROPN'), ('European', 'PROPN'), ('Data', 'PROPN'), ('Protection', 'PROPN'), ('Board', 'PROPN'), ('announced', 'VERB'), ('fine', 'NOUN'), ('statement', 'NOUN'), ('Monday', 'PROPN'), ('saying', 'VERB'), ('followed', 'VERB'), ('inquiry', 'NOUN'), ('Facebook', 'PROPN'), ('FB', 'PROPN'), ('Irish', 'PROPN'), ('Data', 'PROPN'), ('Protection', 'PROPN'), ('Commission', 'PROPN'), ('chief', 'ADJ'), ('regulator', 'NOUN'), ('overseeing', 'VERB'), ('Meta', 'PROPN'), ('operations', 'NOUN'), ('Europe', 'PROPN'), ('highlights', 'VERB'), ('ongoing', 'ADJ'), ('uncertainty', 'NOUN'), ('global', 'ADJ'), ('businesses', 'NOUN'), ('legally', 'ADV'), ('transfer', 'VERB'), ('EU', 'PROPN'), ('users', 'NOUN'), ('data', 'NOUN'), ('servers', 'NOUN'), ('overseas', 'ADV'), ('EU', 'PROPN'), ('regulator', 'NOUN'), ('said', 'VERB'), ('processing', 'NOUN'), ('storage', 'NOUN'), ('personal', 'ADJ'), ('data', 'NOUN'), ('United', 'PROPN'), ('States', 'PROPN'), ('contravened', 'VERB'), ('Europe', 'PROPN'), ('signature', 'NOUN'), ('data', 'NOUN'), ('privacy', 'NOUN'), ('law', 'NOUN'), ('known', 'VERB'), ('General', 'PROPN'), ('Data', 'PROPN'), ('Protection', 'PROPN'), ('Regulation', 'PROPN'), ('Chapter', 'NOUN'), ('GDPR', 'PROPN'), ('sets', 'VERB'), ('conditions', 'NOUN'), ('personal', 'ADJ'), ('data', 'NOUN'), ('transferred', 'VERB'), ('countries', 'NOUN'), ('international', 'ADJ'), ('organizations', 'NOUN')]
# Named Entities: [('Meta', 'ORG'), ('€1.2 billion', 'MONEY'), ('$1.3 billion', 'MONEY'), ('European Union', 'ORG'), ('EU', 'ORG'), ('the United States', 'GPE'), ('The European Data Protection Board', 'ORG'), ('Monday', 'DATE'), ('Facebook (FB', 'WORK_OF_ART'), ('the Irish Data Protection Commission', 'ORG'), ('Meta', 'ORG'), ('Europe', 'LOC'), ('EU', 'ORG'), ('EU', 'ORG'), ('the United States', 'GPE'), ('Europe', 'LOC'), ('the General Data Protection Regulation', 'ORG'), ('Chapter 5', 'LAW'), ('third', 'ORDINAL')]
#
# 3
# Tokens: ['SINGAPORE', 'year', 'old', 'man', 'linked', 'Singapore', 'largest', 'money', 'laundering', 'case', 'sentenced', 'months', 'jail', 'Tuesday', 'Apr', 'Zhang', 'Ruijin', 'ordered', 'forfeit', 'million', 'assets', 'state', 'amounts', 'cent', 'million', 'worth', 'assets', 'originally', 'seized', 'police', 'fifth', 'accused', 'persons', 'dealt', 'relation', 'case', 'Zhang', 'pleaded', 'guilty', 'Tuesday', 'counts', 'forgery', 'related', 'offences', 'failing', 'satisfactorily', 'account', 'property', 'reasonably', 'suspected', 'benefits', 'criminal', 'conduct']
# POS Tags: [('SINGAPORE', 'PROPN'), ('year', 'NOUN'), ('old', 'ADJ'), ('man', 'NOUN'), ('linked', 'VERB'), ('Singapore', 'PROPN'), ('largest', 'ADJ'), ('money', 'NOUN'), ('laundering', 'NOUN'), ('case', 'NOUN'), ('sentenced', 'VERB'), ('months', 'NOUN'), ('jail', 'NOUN'), ('Tuesday', 'PROPN'), ('Apr', 'PROPN'), ('Zhang', 'PROPN'), ('Ruijin', 'PROPN'), ('ordered', 'VERB'), ('forfeit', 'VERB'), ('million', 'NUM'), ('assets', 'NOUN'), ('state', 'NOUN'), ('amounts', 'VERB'), ('cent', 'NOUN'), ('million', 'NUM'), ('worth', 'NOUN'), ('assets', 'NOUN'), ('originally', 'ADV'), ('seized', 'VERB'), ('police', 'NOUN'), ('fifth', 'ADJ'), ('accused', 'VERB'), ('persons', 'NOUN'), ('dealt', 'VERB'), ('relation', 'NOUN'), ('case', 'NOUN'), ('Zhang', 'PROPN'), ('pleaded', 'VERB'), ('guilty', 'ADJ'), ('Tuesday', 'PROPN'), ('counts', 'NOUN'), ('forgery', 'NOUN'), ('related', 'VERB'), ('offences', 'NOUN'), ('failing', 'VERB'), ('satisfactorily', 'ADV'), ('account', 'VERB'), ('property', 'NOUN'), ('reasonably', 'ADV'), ('suspected', 'VERB'), ('benefits', 'NOUN'), ('criminal', 'ADJ'), ('conduct', 'NOUN')]
# Named Entities: [('SINGAPORE', 'GPE'), ('45-year-old', 'DATE'), ('Singapore', 'GPE'), ("15 months'", 'DATE'), ('Tuesday', 'DATE'), ('30', 'CARDINAL'), ('Zhang Ruijin', 'PERSON'), ('about 90', 'CARDINAL'), ('fifth', 'ORDINAL'), ('10', 'CARDINAL'), ('Zhang', 'PERSON'), ('Tuesday', 'DATE'), ('two', 'CARDINAL'), ('one', 'CARDINAL')]
#
# 4
# Tokens: ['Department', 'Education', 'imposed', 'record', 'million', 'fine', 'Liberty', 'University', 'Christian', 'college', 'located', 'Virginia', 'violations', 'campus', 'safety', 'law', 'officials', 'said', 'Tuesday', 'Department', 'Education', 'said', 'largest', 'fine', 'imposed', 'violating', 'Clery', 'Act', 'requires', 'colleges', 'maintain', 'disclose', 'campus', 'crime', 'statistics', 'security', 'information', 'Liberty', 'University', 'agreed', 'spend', 'additional', 'million', 'improve', 'campus', 'safety', 'years', 'Department', 'Education', 'initiated', 'review', 'receiving', 'complaints', 'alleged', 'college', 'committed', 'violations', 'Clery', 'Act', 'review', 'followed', 'lawsuit', 'women', 'claimed', 'school', 'created', 'environment', 'increased', 'likelihood', 'sexual', 'assault', 'rape', 'case', 'settled']
# POS Tags: [('Department', 'PROPN'), ('Education', 'PROPN'), ('imposed', 'VERB'), ('record', 'NOUN'), ('million', 'NUM'), ('fine', 'NOUN'), ('Liberty', 'PROPN'), ('University', 'PROPN'), ('Christian', 'PROPN'), ('college', 'NOUN'), ('located', 'VERB'), ('Virginia', 'PROPN'), ('violations', 'NOUN'), ('campus', 'NOUN'), ('safety', 'NOUN'), ('law', 'NOUN'), ('officials', 'NOUN'), ('said', 'VERB'), ('Tuesday', 'PROPN'), ('Department', 'PROPN'), ('Education', 'PROPN'), ('said', 'VERB'), ('largest', 'ADJ'), ('fine', 'NOUN'), ('imposed', 'VERB'), ('violating', 'VERB'), ('Clery', 'PROPN'), ('Act', 'PROPN'), ('requires', 'VERB'), ('colleges', 'NOUN'), ('maintain', 'VERB'), ('disclose', 'VERB'), ('campus', 'NOUN'), ('crime', 'NOUN'), ('statistics', 'NOUN'), ('security', 'NOUN'), ('information', 'NOUN'), ('Liberty', 'PROPN'), ('University', 'PROPN'), ('agreed', 'VERB'), ('spend', 'VERB'), ('additional', 'ADJ'), ('million', 'NUM'), ('improve', 'VERB'), ('campus', 'NOUN'), ('safety', 'NOUN'), ('years', 'NOUN'), ('Department', 'PROPN'), ('Education', 'PROPN'), ('initiated', 'VERB'), ('review', 'NOUN'), ('receiving', 'VERB'), ('complaints', 'NOUN'), ('alleged', 'VERB'), ('college', 'NOUN'), ('committed', 'VERB'), ('violations', 'NOUN'), ('Clery', 'PROPN'), ('Act', 'PROPN'), ('review', 'NOUN'), ('followed', 'VERB'), ('lawsuit', 'NOUN'), ('women', 'NOUN'), ('claimed', 'VERB'), ('school', 'NOUN'), ('created', 'VERB'), ('environment', 'NOUN'), ('increased', 'VERB'), ('likelihood', 'NOUN'), ('sexual', 'ADJ'), ('assault', 'NOUN'), ('rape', 'NOUN'), ('case', 'NOUN'), ('settled', 'VERB')]
# Named Entities: [('The Department of Education', 'ORG'), ('a record $14 million', 'MONEY'), ('Liberty University', 'ORG'), ('Christian', 'NORP'), ('Virginia', 'GPE'), ('Tuesday', 'DATE'), ('The Department of Education', 'ORG'), ('the Clery Act', 'LAW'), ('Liberty University', 'ORG'), ('an additional $2 million', 'MONEY'), ('the next two years', 'DATE'), ('The Department of Education', 'ORG'), ('2022', 'DATE'), ('the Clery Act', 'LAW'), ('2021', 'DATE'), ('12', 'CARDINAL'), ('2022', 'DATE')]
#
# 5
# Tokens: ['days', 'deliberation', 'Vienna', 'court', 'delivered', 'verdict', 'trial', 'Austrian', 'Chancellor', 'Sebastian', 'Kurz', 'convicted', 'making', 'false', 'statements', 'parliamentary', 'inquiry', 'verdict', 'Vienna', 'criminal', 'court', 'followed', 'month', 'trial', 'case', 'marked', 'time', 'years', 'Austrian', 'chancellor', 'stood', 'trial', 'given', 'month', 'suspended', 'sentence', 'Kurz', 'hailed', 'wunderkind', 'Austrian', 'People', 'Party', 'resigned', 'following', 'separate', 'corruption', 'probe', 'Prosecutors', 'trial', 'opened', 'October', 'accused', 'year', 'old', 'giving', 'false', 'evidence', 'June', 'inquiry', 'role', 'setting', 'holding', 'company', 'named', 'OeBAG']
# POS Tags: [('days', 'NOUN'), ('deliberation', 'NOUN'), ('Vienna', 'PROPN'), ('court', 'NOUN'), ('delivered', 'VERB'), ('verdict', 'NOUN'), ('trial', 'NOUN'), ('Austrian', 'PROPN'), ('Chancellor', 'PROPN'), ('Sebastian', 'PROPN'), ('Kurz', 'PROPN'), ('convicted', 'VERB'), ('making', 'VERB'), ('false', 'ADJ'), ('statements', 'NOUN'), ('parliamentary', 'ADJ'), ('inquiry', 'NOUN'), ('verdict', 'NOUN'), ('Vienna', 'PROPN'), ('criminal', 'ADJ'), ('court', 'NOUN'), ('followed', 'VERB'), ('month', 'NOUN'), ('trial', 'NOUN'), ('case', 'NOUN'), ('marked', 'VERB'), ('time', 'NOUN'), ('years', 'NOUN'), ('Austrian', 'ADJ'), ('chancellor', 'NOUN'), ('stood', 'VERB'), ('trial', 'NOUN'), ('given', 'VERB'), ('month', 'NOUN'), ('suspended', 'VERB'), ('sentence', 'NOUN'), ('Kurz', 'PROPN'), ('hailed', 'VERB'), ('wunderkind', 'NOUN'), ('Austrian', 'PROPN'), ('People', 'PROPN'), ('Party', 'PROPN'), ('resigned', 'VERB'), ('following', 'VERB'), ('separate', 'ADJ'), ('corruption', 'NOUN'), ('probe', 'NOUN'), ('Prosecutors', 'NOUN'), ('trial', 'NOUN'), ('opened', 'VERB'), ('October', 'PROPN'), ('accused', 'VERB'), ('year', 'NOUN'), ('old', 'ADJ'), ('giving', 'VERB'), ('false', 'ADJ'), ('evidence', 'NOUN'), ('June', 'PROPN'), ('inquiry', 'NOUN'), ('role', 'NOUN'), ('setting', 'VERB'), ('holding', 'VERB'), ('company', 'NOUN'), ('named', 'VERB'), ('OeBAG', 'NUM')]
# Named Entities: [('twelve days', 'DATE'), ('Vienna', 'GPE'), ('Austrian', 'NORP'), ('Sebastian Kurz', 'PERSON'), ('Vienna', 'GPE'), ('four-month', 'DATE'), ('first', 'ORDINAL'), ('more than 30 years', 'DATE'), ('Austrian', 'NORP'), ('eight-month', 'DATE'), ('Kurz', 'PERSON'), ("the Austrian People's Party", 'ORG'), ('2021', 'DATE'), ('October', 'DATE'), ('37-year-old', 'DATE'), ('June 2020', 'DATE')]
#
# 6
# Tokens: ['China', 'cyberspace', 'regulator', 'fined', 'Didi', 'Global', 'billion', 'yuan', 'billion', 'Thursday', 'violating', 'cybersecurity', 'data', 'laws', 'putting', 'end', 'yearlong', 'investigation', 'ride', 'hailing', 'giant', 'Cyberspace', 'Administration', 'China', 'CAC', 'said', 'statement', 'firm', 'breached', 'country', 'cybersecurity', 'law', 'data', 'security', 'law', 'personal', 'information', 'protection', 'law', 'facts', 'violations', 'laws', 'regulations', 'clear', 'evidence', 'conclusive', 'circumstances', 'nature', 'vile', 'statement', 'added', 'Aside', 'billion', 'penalty', 'regulator', 'imposed', 'personal', 'fine', 'million', 'yuan', 'Didi', 'chairman', 'CEO', 'Cheng', 'Wei', 'president', 'Liu', 'Qing', 'respectively', 'Liu', 'Qing', 'known', 'Jean', 'Liu', 'English']
# POS Tags: [('China', 'PROPN'), ('cyberspace', 'NOUN'), ('regulator', 'NOUN'), ('fined', 'VERB'), ('Didi', 'PROPN'), ('Global', 'PROPN'), ('billion', 'NUM'), ('yuan', 'NOUN'), ('billion', 'NUM'), ('Thursday', 'PROPN'), ('violating', 'VERB'), ('cybersecurity', 'NOUN'), ('data', 'NOUN'), ('laws', 'NOUN'), ('putting', 'VERB'), ('end', 'NOUN'), ('yearlong', 'ADJ'), ('investigation', 'NOUN'), ('ride', 'NOUN'), ('hailing', 'VERB'), ('giant', 'NOUN'), ('Cyberspace', 'PROPN'), ('Administration', 'PROPN'), ('China', 'PROPN'), ('CAC', 'PROPN'), ('said', 'VERB'), ('statement', 'NOUN'), ('firm', 'NOUN'), ('breached', 'VERB'), ('country', 'NOUN'), ('cybersecurity', 'NOUN'), ('law', 'NOUN'), ('data', 'NOUN'), ('security', 'NOUN'), ('law', 'NOUN'), ('personal', 'ADJ'), ('information', 'NOUN'), ('protection', 'NOUN'), ('law', 'NOUN'), ('facts', 'NOUN'), ('violations', 'NOUN'), ('laws', 'NOUN'), ('regulations', 'NOUN'), ('clear', 'ADJ'), ('evidence', 'NOUN'), ('conclusive', 'ADJ'), ('circumstances', 'NOUN'), ('nature', 'NOUN'), ('vile', 'ADJ'), ('statement', 'NOUN'), ('added', 'VERB'), ('Aside', 'ADV'), ('billion', 'NUM'), ('penalty', 'NOUN'), ('regulator', 'NOUN'), ('imposed', 'VERB'), ('personal', 'ADJ'), ('fine', 'NOUN'), ('million', 'NUM'), ('yuan', 'NOUN'), ('Didi', 'PROPN'), ('chairman', 'NOUN'), ('CEO', 'PROPN'), ('Cheng', 'PROPN'), ('Wei', 'PROPN'), ('president', 'PROPN'), ('Liu', 'PROPN'), ('Qing', 'PROPN'), ('respectively', 'ADV'), ('Liu', 'PROPN'), ('Qing', 'PROPN'), ('known', 'VERB'), ('Jean', 'PROPN'), ('Liu', 'PROPN'), ('English', 'PROPN')]
# Named Entities: [('China', 'GPE'), ('Didi Global', 'PERSON'), ('8 billion yuan', 'MONEY'), ('$1.2 billion', 'MONEY'), ('Thursday', 'DATE'), ('The Cyberspace Administration of China', 'ORG'), ('CAC', 'ORG'), ('$1.19 billion', 'MONEY'), ('1 million yuan', 'MONEY'), ('147,000', 'MONEY'), ('Didi', 'ORG'), ('Cheng Wei', 'PERSON'), ('Liu Qing', 'PERSON'), ('Liu Qing', 'PERSON'), ('Jean Liu', 'PERSON'), ('English', 'LANGUAGE')]
#
# 7
# Tokens: ['Thursday', 'Brussels', 'Criminal', 'Court', 'prosecutor', 'requested', 'year', 'prison', 'sentences', 'Alfredo', 'Indrit', 'Black', 'Eagle', 'case', 'related', 'large', 'drug', 'trafficking', 'operation', 'identified', 'Albanian', 'nationals', 'leaders', 'criminal', 'organisation', 'responsible', 'drug', 'trafficking', 'operation', 'Prosecution', 'evidence', 'includes', 'cocaine', 'seizures', 'conducted', 'investigation', 'launched', 'estimated', 'value', 'million', 'Alfredo', 'pinpointed', 'operation', 'heads', 'found', 'connections', 'Italian', 'mafia', 'groups', 'established', 'Limburg', 'heads', 'larger', 'organisation', 'based', 'Majorca', 'implemented', 'modern', 'business', 'methods', 'sharing', 'resources', 'workforce', 'equipment', 'explained', 'prosecutor']
# POS Tags: [('Thursday', 'PROPN'), ('Brussels', 'PROPN'), ('Criminal', 'PROPN'), ('Court', 'PROPN'), ('prosecutor', 'NOUN'), ('requested', 'VERB'), ('year', 'NOUN'), ('prison', 'NOUN'), ('sentences', 'NOUN'), ('Alfredo', 'PROPN'), ('Indrit', 'PROPN'), ('Black', 'PROPN'), ('Eagle', 'PROPN'), ('case', 'NOUN'), ('related', 'VERB'), ('large', 'ADJ'), ('drug', 'NOUN'), ('trafficking', 'NOUN'), ('operation', 'NOUN'), ('identified', 'VERB'), ('Albanian', 'ADJ'), ('nationals', 'NOUN'), ('leaders', 'NOUN'), ('criminal', 'ADJ'), ('organisation', 'NOUN'), ('responsible', 'ADJ'), ('drug', 'NOUN'), ('trafficking', 'NOUN'), ('operation', 'NOUN'), ('Prosecution', 'NOUN'), ('evidence', 'NOUN'), ('includes', 'VERB'), ('cocaine', 'NOUN'), ('seizures', 'NOUN'), ('conducted', 'VERB'), ('investigation', 'NOUN'), ('launched', 'VERB'), ('estimated', 'VERB'), ('value', 'NOUN'), ('million', 'NUM'), ('Alfredo', 'PROPN'), ('pinpointed', 'VERB'), ('operation', 'NOUN'), ('heads', 'NOUN'), ('found', 'VERB'), ('connections', 'NOUN'), ('Italian', 'ADJ'), ('mafia', 'NOUN'), ('groups', 'NOUN'), ('established', 'VERB'), ('Limburg', 'PROPN'), ('heads', 'NOUN'), ('larger', 'ADJ'), ('organisation', 'NOUN'), ('based', 'VERB'), ('Majorca', 'PROPN'), ('implemented', 'VERB'), ('modern', 'ADJ'), ('business', 'NOUN'), ('methods', 'NOUN'), ('sharing', 'VERB'), ('resources', 'NOUN'), ('workforce', 'NOUN'), ('equipment', 'NOUN'), ('explained', 'VERB'), ('prosecutor', 'NOUN')]
# Named Entities: [('Thursday', 'DATE'), ('the Brussels Criminal Court’s', 'ORG'), ('20-year', 'DATE'), ('Alfredo H.', 'PERSON'), ('two', 'CARDINAL'), ('Albanian', 'NORP'), ('2020', 'DATE'), ('€13.42 million', 'MONEY'), ('Alfredo H.', 'PERSON'), ('Italian', 'NORP'), ('Limburg', 'GPE'), ('Majorca', 'ORG')]
#
# 8
# Tokens: ['Prague', 'District', 'Court', 'morning', 'sentenced', 'member', 'parliament', 'MP', 'Dominik', 'Feri', 'years', 'prison', 'rapes', 'attempted', 'rape', 'finding', 'guilty', 'counts', 'indictments', 'Feri', 'ordered', 'pay', 'total', 'CZK', 'financial', 'compensation', 'victims', 'verdict', 'final', 'Feri', 'expected', 'appeal', 'Prague', 'Metropolitan', 'Court', 'MP', 'party', 'Feri', 'accused', 'committing', 'acts', 'apartment', 'Chamber', 'Deputies', 'building', 'years', 'later']
# POS Tags: [('Prague', 'PROPN'), ('District', 'PROPN'), ('Court', 'PROPN'), ('morning', 'NOUN'), ('sentenced', 'VERB'), ('member', 'NOUN'), ('parliament', 'PROPN'), ('MP', 'PROPN'), ('Dominik', 'PROPN'), ('Feri', 'PROPN'), ('years', 'NOUN'), ('prison', 'NOUN'), ('rapes', 'NOUN'), ('attempted', 'VERB'), ('rape', 'NOUN'), ('finding', 'VERB'), ('guilty', 'ADJ'), ('counts', 'NOUN'), ('indictments', 'NOUN'), ('Feri', 'PROPN'), ('ordered', 'VERB'), ('pay', 'VERB'), ('total', 'NOUN'), ('CZK', 'PROPN'), ('financial', 'ADJ'), ('compensation', 'NOUN'), ('victims', 'NOUN'), ('verdict', 'NOUN'), ('final', 'ADJ'), ('Feri', 'PROPN'), ('expected', 'VERB'), ('appeal', 'VERB'), ('Prague', 'PROPN'), ('Metropolitan', 'PROPN'), ('Court', 'PROPN'), ('MP', 'PROPN'), ('party', 'NOUN'), ('Feri', 'PROPN'), ('accused', 'VERB'), ('committing', 'VERB'), ('acts', 'NOUN'), ('apartment', 'NOUN'), ('Chamber', 'PROPN'), ('Deputies', 'PROPN'), ('building', 'VERB'), ('years', 'NOUN'), ('later', 'ADV')]
# Named Entities: [('Prague', 'GPE'), ('3', 'CARDINAL'), ('this morning', 'TIME'), ('Dominik Feri', 'PERSON'), ('three years', 'DATE'), ('two', 'CARDINAL'), ('one', 'CARDINAL'), ('Feri', 'ORG'), ('27', 'DATE'), ('CZK', 'ORG'), ('Feri', 'ORG'), ('the Prague Metropolitan Court', 'ORG'), ('09', 'CARDINAL'), ('between 2017 and 2021', 'DATE'), ('Feri', 'ORG'), ('two', 'CARDINAL'), ('2016', 'DATE'), ('the Chamber of Deputies', 'ORG'), ('two years later', 'DATE')]
#
# 9
# Tokens: ['Sanjay', 'Shah', 'arrested', 'June', 'Dubai', 'living', 'accused', 'running', 'billion', 'kroner', 'billion', 'scam', 'enabled', 'companies', 'controlled', 'fraudulently', 'claim', 'Danish', 'tax', 'refunds', 'Shah', 'said', 'guilty', 'violate', 'Danish', 'law', 'faces', 'years', 'prison', 'Glostrup', 'district', 'court', 'Copenhagen', 'finds', 'guilty', 'United', 'Arab', 'Emirates', 'extradited', 'Shah', 'Denmark', 'December', 'years', 'negotiations', 'included', 'signing', 'extradition', 'treaty', 'countries', 'March', 'prosecution', 'said', 'statement', 'Shah', 'designed', 'organised', 'fraud', 'scheme', 'submit', 'applications', 'unlawfully', 'receive', 'billion', 'kroner', 'dividend', 'tax', 'refunds', 'Treasury']
# POS Tags: [('Sanjay', 'PROPN'), ('Shah', 'PROPN'), ('arrested', 'VERB'), ('June', 'PROPN'), ('Dubai', 'PROPN'), ('living', 'VERB'), ('accused', 'VERB'), ('running', 'VERB'), ('billion', 'NUM'), ('kroner', 'NOUN'), ('billion', 'NUM'), ('scam', 'NOUN'), ('enabled', 'VERB'), ('companies', 'NOUN'), ('controlled', 'VERB'), ('fraudulently', 'ADV'), ('claim', 'VERB'), ('Danish', 'ADJ'), ('tax', 'NOUN'), ('refunds', 'NOUN'), ('Shah', 'PROPN'), ('said', 'VERB'), ('guilty', 'ADJ'), ('violate', 'VERB'), ('Danish', 'ADJ'), ('law', 'NOUN'), ('faces', 'VERB'), ('years', 'NOUN'), ('prison', 'NOUN'), ('Glostrup', 'PROPN'), ('district', 'NOUN'), ('court', 'NOUN'), ('Copenhagen', 'PROPN'), ('finds', 'VERB'), ('guilty', 'ADJ'), ('United', 'PROPN'), ('Arab', 'PROPN'), ('Emirates', 'PROPN'), ('extradited', 'VERB'), ('Shah', 'PROPN'), ('Denmark', 'VERB'), ('December', 'PROPN'), ('years', 'NOUN'), ('negotiations', 'NOUN'), ('included', 'VERB'), ('signing', 'NOUN'), ('extradition', 'NOUN'), ('treaty', 'NOUN'), ('countries', 'NOUN'), ('March', 'PROPN'), ('prosecution', 'NOUN'), ('said', 'VERB'), ('statement', 'NOUN'), ('Shah', 'PROPN'), ('designed', 'VERB'), ('organised', 'VERB'), ('fraud', 'NOUN'), ('scheme', 'NOUN'), ('submit', 'VERB'), ('applications', 'NOUN'), ('unlawfully', 'ADV'), ('receive', 'VERB'), ('billion', 'NUM'), ('kroner', 'NOUN'), ('dividend', 'NOUN'), ('tax', 'NOUN'), ('refunds', 'NOUN'), ('Treasury', 'PROPN')]
# Named Entities: [('Sanjay Shah', 'PERSON'), ('June 2022', 'DATE'), ('Dubai', 'GPE'), ('nine-billion-kroner', 'MONEY'), ('$1.32-billion', 'MONEY'), ('Danish', 'NORP'), ('between 2012 and 2015', 'DATE'), ('Shah', 'PERSON'), ('53', 'DATE'), ('Danish', 'NORP'), ('up to 12 years', 'DATE'), ('Glostrup', 'PERSON'), ('Copenhagen', 'ORG'), ('The United Arab Emirates', 'GPE'), ('Shah', 'ORG'), ('Denmark', 'GPE'), ('December', 'DATE'), ('years', 'DATE'), ('two', 'CARDINAL'), ('March 2022', 'DATE'), ('Shah', 'ORG'), ('more than 3,000', 'CARDINAL'), ('more than nine billion kroner', 'MONEY'), ('Treasury', 'ORG')]
